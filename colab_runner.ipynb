# %% [markdown]
# # Clone the repository
# Run the cell below to fetch the project from GitHub.

# %%
print("Hello, World!")
import os
# %cd ../content
# Current working directory
print("Current working directory:", os.getcwd())
# Clone the repository
# !ls
# !rm -rf Clustering-and-Similarity-Search-Algorithms
# !git clone -b test-NLSH --single-branch https://github.com/sdi1700058/Clustering-and-Similarity-Search-Algorithms.git
# %cd Clustering-and-Similarity-Search-Algorithms
# Download the SIFT dataset
# %cd data/
# !rm -rf sift
# !wget -O sift.tar.gz ftp://ftp.irisa.fr/local/texmex/corpus/sift.tar.gz
# !mkdir sift
# !tar -xvzf sift.tar.gz -C sift/ --strip-components 1
# !rm sift.tar.gz
# !ls sift/
# %cd ..
#print("Changed working directory to:", os.getcwd())
# !ls
# Run the NLSH scripts
# Check dependencies and install if needed
# %cd NLSH/
print("Changed working directory to:", os.getcwd())
# !pip install numpy scipy scikit-learn faiss-cpu pybind11 kahip
# Run the NLSH build script with specified parameters
# !python3 nlsh_build.py -d "../data/sift/sift_base.fvecs" -q "../data/sift/sift_query.fvecs" -o "output.txt" -type sift -knn 5 -m 100 -imbalance 0.03 -kahip_mode 0 -layers 3 -nodes 64 -epochs 10 -batch_size 128 -lr 0.0001 -seed 1
# Out:
# Hello, World!
# /content
# Current working directory: /content
# Clustering-and-Similarity-Search-Algorithms  sample_data
# Cloning into 'Clustering-and-Similarity-Search-Algorithms'...
# remote: Enumerating objects: 253, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 253 (delta 15), reused 16 (delta 13), pack-reused 215 (from 1)
# Receiving objects: 100% (253/253), 24.55 MiB | 16.37 MiB/s, done.
# Resolving deltas: 100% (97/97), done.
# /content/Clustering-and-Similarity-Search-Algorithms
# /content/Clustering-and-Similarity-Search-Algorithms/data
# --2025-12-05 18:20:21--  ftp://ftp.irisa.fr/local/texmex/corpus/sift.tar.gz
#            => ‘sift.tar.gz’
# Resolving ftp.irisa.fr (ftp.irisa.fr)... 131.254.254.45, 2001:660:7303:254::45
# Connecting to ftp.irisa.fr (ftp.irisa.fr)|131.254.254.45|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /local/texmex/corpus ... done.
# ==> SIZE sift.tar.gz ... 168280445
# ==> PASV ... done.    ==> RETR sift.tar.gz ... done.
# Length: 168280445 (160M) (unauthoritative)
#
# sift.tar.gz         100%[===================>] 160.48M  20.8MB/s    in 8.5s
#
# 2025-12-05 18:20:31 (18.9 MB/s) - ‘sift.tar.gz’ saved [168280445]
#
# sift/sift_base.fvecs
# sift/sift_groundtruth.ivecs
# sift/sift_learn.fvecs
# sift/sift_query.fvecs
# sift_base.fvecs  sift_groundtruth.ivecs  sift_learn.fvecs  sift_query.fvecs
# /content/Clustering-and-Similarity-Search-Algorithms
# colab_runner.ipynb  data  include  Makefile  NLSH  output  README.md  src  val
# /content/Clustering-and-Similarity-Search-Algorithms/NLSH
# Changed working directory to: /content/Clustering-and-Similarity-Search-Algorithms/NLSH
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.13.1)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.12/dist-packages (3.0.1)
# Requirement already satisfied: kahip in /usr/local/lib/python3.12/dist-packages (3.22)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
