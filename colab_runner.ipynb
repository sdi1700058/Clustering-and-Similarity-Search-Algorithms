# %% [markdown]
# # Clone the repository
# Run the cell below to fetch the project from GitHub.

# %%
print("Hello, World!")
import os
# Current working directory
print("Current working directory:", os.getcwd())
# Clonde the repository
# %cd ..
print("Changed working directory to:", os.getcwd())
# !rm -rf Clustering-and-Similarity-Search-Algorithms
# !git clone -b test-NLSH --single-branch https://github.com/sdi1700058/Clustering-and-Similarity-Search-Algorithms.git
# %cd Clustering-and-Similarity-Search-Algorithms
print("Changed working directory to:", os.getcwd())
# !ls
# Run the NLSH scripts
# Check dependencies and install if needed
# !pip install numpy scipy scikit-learn faiss-cpu pybind11 kahip
# Run the NLSH build script with specified parameters
# !python3 NLSH/nlsh_build.py -d "../data/sift/sift_base.fvecs" -q "../data/sift/sift_query.fvecs" -o "output.txt" -type sift -knn 5 -m 100 -imbalance 0.03 -kahip_mode 0 -layers 3 -nodes 64 -epochs 10 -batch_size 128 -lr 0.0001 -seed 1
# Out:
# Hello, World!
# Current working directory: /content/Clustering-and-Similarity-Search-Algorithms
# /content
# Changed working directory to: /content
# Cloning into 'Clustering-and-Similarity-Search-Algorithms'...
# remote: Enumerating objects: 247, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 247 (delta 15), reused 13 (delta 13), pack-reused 215 (from 1)
# Receiving objects: 100% (247/247), 24.54 MiB | 23.75 MiB/s, done.
# Resolving deltas: 100% (97/97), done.
# /content/Clustering-and-Similarity-Search-Algorithms
# Changed working directory to: /content/Clustering-and-Similarity-Search-Algorithms
# data  include  Makefile  NLSH  output  README.md  src  val
# ...
# Traceback (most recent call last):
#   File "/content/Clustering-and-Similarity-Search-Algorithms/NLSH/nlsh_build.py", line 22, in <module>
#     from data_parser import get_dataset, search_parser, build_parser
# ...
